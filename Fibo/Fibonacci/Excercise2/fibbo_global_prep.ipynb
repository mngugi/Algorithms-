# %%
print(0)
print(1)

count = 2

def fibo_global_count(first_num, second_num):
    global count

    if count <= 20:
        new_Fibonnaci = first_num + second_num
        print(new_Fibonnaci)
        second_num = first_num
        first_num = new_Fibonnaci
        count +=1
        fibo_global_count(new_Fibonnaci, first_num)

    else:
        return
fibo_global_count(1,0)
# Out:
# 0
# 1
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
