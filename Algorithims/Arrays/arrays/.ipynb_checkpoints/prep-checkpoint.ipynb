# %%
arr = [9,7,1,6,2,0.5,0.15]
smallest_element = arr[0]

for i in arr:
    if i < smallest_element:
        smallest_element = i

print(f'The smallest element in the array is {smallest_element}')
# Out:
# The smallest element in the array is 0.15
