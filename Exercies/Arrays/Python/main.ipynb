# %%
import arrayCall

arr = [0.1,0.99,0.0999,0.99999,1,1.0002]

getMin = arrayCall.find_min(arr)
getMax = arrayCall.find_max(arr)

print(f'the minimal element is {getMin}')
print(f'the maximum element {getMax}')
# Out:
# the minimal element is 0.0999
# the maximum element 1.0002
